# %% [markdown]
# <a href="https://colab.research.google.com/github/mayhong1/COGS108_Repo/blob/main/MusicGen_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# Remove existing audiocraft directory if it exists to ensure a clean clone
if os.path.exists('/content/audiocraft'):
    # !rm -rf /content/audiocraft

# %cd /content
# !git clone -b v1.0 https://github.com/camenduru/audiocraft
# %cd /content/audiocraft

# Upgrade pip and install build essentials
# !pip install --upgrade pip setuptools wheel

# Install project requirements
# !pip install -r requirements.txt

# Run the application
# !python app.py --share
# Out:
# /content
# Cloning into 'audiocraft'...
# remote: Enumerating objects: 1258, done.
# remote: Counting objects: 100% (379/379), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 1258 (delta 319), reused 315 (delta 315), pack-reused 879 (from 1)
# Receiving objects: 100% (1258/1258), 1.73 MiB | 18.09 MiB/s, done.
# Resolving deltas: 100% (718/718), done.
# /content/audiocraft
# ...
#   Using cached flashy-0.0.2.tar.gz (72 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached hydra_colorlog-1.2.0-py3-none-any.whl.metadata (949 bytes)
# ...
#   Using cached julius-0.2.7.tar.gz (59 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# ...

# %%
# !pip install av

# %%
# !pip install einops

# %%
# !pip install 'flashy>=0.0.1'
# Out:
# ...
#   Using cached flashy-0.0.2.tar.gz (72 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for flashy: filename=flashy-0.0.2-py3-none-any.whl size=34623 sha256=fe16b67ba1a6b902f97bab94a6c103e98e926be8c434e3f3dcc8d8c557f8358f
#   Stored in directory: /root/.cache/pip/wheels/5b/35/04/49a26fd4d058837cc1a9fe96b37e9174476d7c4dc1ea200655
# ...
#   Created wheel for dora_search: filename=dora_search-0.1.12-py3-none-any.whl size=75195 sha256=1deda07c27d14ce2a36ac8dc8db5f5ca2f26f354492b1672261fbc0fd64b0901
#   Stored in directory: /root/.cache/pip/wheels/55/40/4c/3478187386b56625ab5aa8a9070ff1eea704ddb27d15abe73f
# Successfully built flashy dora_search
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [flashy]
# ...

# %%
# !pip install 'hydra-core>=1.1'
# Out:
# ...
#   Using cached hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# ...

# %%
# !pip install hydra_colorlog
# Out:
# ...
#   Using cached hydra_colorlog-1.2.0-py3-none-any.whl.metadata (949 bytes)
# ...

# %%
# !pip install julius
# Out:
# ...
#   Using cached julius-0.2.7.tar.gz (59 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=21966 sha256=ff6120b56a1d1100a11bf41bff6d8e0cf680f5574e59fbefe576119f498b9258
#   Stored in directory: /root/.cache/pip/wheels/de/c1/ca/544dafe48401e8e2e17064dfe465a390fca9e8720ffa12e744
# Successfully built julius
# ...

# %%
# !pip install num2words
# Out:
# ...
#   Using cached num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13782 sha256=2bf8b01c202e3ffbd8714145dc63ac65e8b390d60b5e059c7f368e3635f7b760
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built docopt
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [num2words]
# ...

# %%
# !pip install numpy

# %%
# !pip install sentencepiece

# %%
# !pip install 'spacy>=3.6.1'

# %%
# !pip install 'torch==2.10.0'

# %%
# !pip install 'torchaudio>=2.0.0'

# %%
# !pip install huggingface_hub

# %%
# !pip install tqdm

# %%
# !pip install 'transformers>=4.31.0'

# %%
# !pip install xformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 24.6 MB/s  0:00:00
# ...

# %%
# !pip install demucs
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.8 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for demucs: filename=demucs-4.0.1-py3-none-any.whl size=78481 sha256=1029137b0b145447f33907b3c7db07d013bacde4ac2f300624a6007792ff08dc
#   Stored in directory: /root/.cache/pip/wheels/1b/0c/20/a3b3daa1f9b65c8b0445729f94740ec335d0f86f1066c5c414
# Successfully built demucs
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [demucs]
# ...

# %%
# !pip install librosa

# %%
# !pip install gradio

# %%
# !pip install torchmetrics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 15.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [torchmetrics]
# ...

# %%
# !pip install encodec
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 21.0 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for encodec: filename=encodec-0.1.1-py3-none-any.whl size=45852 sha256=4b9f83b58c12715007f01eacd274cbb86accb5fd4930a09b6387444cc5ad373c
#   Stored in directory: /root/.cache/pip/wheels/b8/eb/9f/e13610cc46ab39d3199fbabebd1c3e142d44b679526e0f228a
# Successfully built encodec
# ...

# %%
# !pip install protobuf

# %%
pip install av

# %%
# !python /content/audiocraft/app.py --share
# Out:
# 2026-05-08 21:09:01.937595: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Traceback (most recent call last):
#   File "/content/audiocraft/app.py", line 367, in <module>
#     ui_full(launch_kwargs)
#   File "/content/audiocraft/app.py", line 174, in ui_full
#     melody = gr.Audio(source="upload", type="numpy", label="Melody Condition (optional)", interactive=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/component_meta.py", line 189, in wrapper
#     return fn(self, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
# TypeError: Audio.__init__() got an unexpected keyword argument 'source'

# %%
# !cat /content/audiocraft/app.py
# Out:
# # Copyright (c) Meta Platforms, Inc. and affiliates.
# # All rights reserved.
#
# # This source code is licensed under the license found in the
# # LICENSE file in the root directory of this source tree.
#
# # Updated to account for UI changes from https://github.com/rkfg/audiocraft/blob/long/app.py
# # also released under the MIT license.
#
# import argparse
# from concurrent.futures import ProcessPoolExecutor
# import os
# import subprocess as sp
# from tempfile import NamedTemporaryFile
# import time
# import warnings
#
# import torch
# import gradio as gr
#
# from audiocraft.data.audio_utils import convert_audio
# from audiocraft.data.audio import audio_write
# from audiocraft.models import MusicGen
# import subprocess, random, string
#
#
# MODEL = None  # Last used model
# IS_BATCHED = "facebook/MusicGen" in os.environ.get('SPACE_ID', '')
# MAX_BATCH_SIZE = 12
# BATCHED_DURATION = 15
# INTERRUPTING = False
# ...

# %%
# !sed -i 's/source="upload", //' /content/audiocraft/app.py

# %%
# !python /content/audiocraft/app.py --share
# Out:
# 2026-05-08 21:10:29.995278: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://41c9056757115b78be.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
